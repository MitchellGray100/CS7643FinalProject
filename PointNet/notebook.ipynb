# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
import os

folder_dir = "/content/drive/MyDrive/Colab_Notebooks/PointNet"

os.chdir(folder_dir)
print("this dir:", os.getcwd())

# %%
local_data_dir = "/content/data"

# !mkdir -p $local_data_dir

# !cp "/content/drive/MyDrive/Colab_Notebooks/PointNet/zipped_data/ModelNet40_processed.zip" $local_data_dir
# !cp "/content/drive/MyDrive/Colab_Notebooks/PointNet/zipped_data/ModelNet10_processed.zip" $local_data_dir


# %cd $local_data_dir
# !unzip -q ModelNet40_processed.zip
# !unzip -q ModelNet10_processed.zip

print("unzipped in", local_data_dir)

# %%
import torch
print("cuda:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("device:", torch.cuda.get_device_name(0))

# %%
# !pip install torch torchvision
# !pip install torch_geometric

# %%
import os
value = os.environ.pop("MODELNET_ROOT", None)
print("MODELNET_ROOT was:", value)

# %% [markdown]
# RUN

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/PointNet
# !python search.py
